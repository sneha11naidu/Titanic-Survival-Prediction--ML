# %% [markdown]
# # Titanic Survival Dataset

# %% [markdown]
# # Data Extraction

# %%
import pandas as pd

Titanic_df = pd.read_csv('Titanic_coursework_entire_dataset_23-24.csv')
# print(housing_df)
print(type(Titanic_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# # Data Analysis and Visualisation

# %%
Titanic_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1     3.0                            Braund, Mr. Owen Harris
# 1              2     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3     3.0                             Heikkinen, Miss. Laina
# 3              4     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5     3.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886     2.0                              Montvila, Rev. Juozas
# 886          887     1.0                       Graham, Miss. Margaret Edith
# 887          888     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 888          889     1.0                              Behr, Mr. Karl Howell
# 889          890     3.0                                Dooley, Mr. Patrick
#
# ...

# %%
# Titanic_df.head()
Titanic_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1     3.0                            Braund, Mr. Owen Harris
# 1              2     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3     3.0                             Heikkinen, Miss. Laina
# 3              4     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5     3.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886     2.0                              Montvila, Rev. Juozas
# 886          887     1.0                       Graham, Miss. Margaret Edith
# 887          888     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 888          889     1.0                              Behr, Mr. Karl Howell
# 889          890     3.0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Sex'].value_counts()
#     for x_label, grp in _df_20.groupby('Name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Name')
# _ = plt.ylabel('Sex')

# %%
Titanic_df.shape
# Out:
# (890, 11)

# %%
Titanic_df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'Survival'],
#       dtype='object')

# %%
Titanic_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1     3.0                            Braund, Mr. Owen Harris
# 1              2     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3     3.0                             Heikkinen, Miss. Laina
# 3              4     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5     3.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886     2.0                              Montvila, Rev. Juozas
# 886          887     1.0                       Graham, Miss. Margaret Edith
# 887          888     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 888          889     1.0                              Behr, Mr. Karl Howell
# 889          890     3.0                                Dooley, Mr. Patrick
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming trn_df is your DataFrame and it contains 'Pclass' and 'Survived' columns
# Make sure 'Pclass' is of type 'category' to enforce the order in the plot
Titanic_df['Pclass'] = pd.Categorical(Titanic_df['Pclass'], categories=[1, 2, 3], ordered=True)

# Set up the size of the figure
plt.figure(figsize=(6, 4))

# Create a count plot with Seaborn
sns.countplot(x='Pclass', hue='Survival', data=Titanic_df, palette='Blues')

# Set the title and labels of the plot
plt.title('Survival Count based on Socio-Economic Status (Pclass)')
plt.xlabel('Pclass (Passenger Class)')
plt.ylabel('Count')

# Set the legend
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])

# Show the plot
plt.show()

# %% [markdown]
# Its clear that the 1st class survived more than the other two classes

# %%
# Visualizing Survival Based on Gender

# Set up the size of the figure
plt.figure(figsize=(6, 4))

# Create a count plot with Seaborn for Gender
sns.countplot(x='Sex', hue='Survival', data=Titanic_df, palette='Pastel1')

# Set the title and labels of the plot
plt.title('Survival Count based on Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Set the legend
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])

# Show the plot
plt.show()

# %%
# Visualizing Survival Based on Age

# Set up the size of the figure
plt.figure(figsize=(6, 4))

# Create a histogram plot with Seaborn for Age
sns.histplot(data=Titanic_df, x='Age', hue='Survival', multiple='stack', palette='Pastel2', binwidth=10)

# Set the title and labels of the plot
plt.title('Survival Count based on Age Groups')
plt.xlabel('Age Groups')
plt.ylabel('Count')

# Set the legend
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])

# Show the plot
plt.show()

# %%
# We will create a bar plot for Surival rate of men and women

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming trn_df is your DataFrame and it contains 'Sex' and 'Survived' columns

# Set up the size of the figure
plt.figure(figsize=(10, 6))

# Create a count plot with Seaborn for Gender and Survived
# This will create separate bars for each combination of 'Sex' and 'Survived'
sns.countplot(x='Sex', hue='Survival', data=Titanic_df, palette='Set1')

# Set the title and labels of the plot
plt.title('Distribution of Gender and Survived')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers Survived')

# Set the legend
plt.legend(title='Survived', loc='upper right', labels=['Not Survived', 'Survived'])

# Show the plot
plt.show()

# %%
# We will create a bar plot for Surival rate of men and women based on Pclass

# We'll use seaborn's barplot to achieve this
plt.figure(figsize=(10, 6))
sns.barplot(x='Sex', y='Survival', hue='Pclass', data=Titanic_df, ci=None)

plt.title('Survival by Gender and Pclass')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.legend(title='Pclass', loc='upper left')

plt.show()
# Out:
# <ipython-input-12-548d01bd4743>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Sex', y='Survival', hue='Pclass', data=Titanic_df, ci=None)

# %%
# Grouping Titanic Data by Gender and Passenger Class for Statistical Summary

# This code segment groups the Titanic dataset by gender (Sex) and passenger class (Pclass).
# It computes the average values for all numerical columns within each group.
# The resulting DataFrame provides insights into how different factors like age, fare,
# and family size correlate with passenger survival rates across genders and classes.

# Group the data by 'Sex' and 'Pclass' and calculate the mean for each numerical column
grouped_df = Titanic_df.groupby(['Sex', 'Pclass']).mean()

# Display the resulting DataFrame
print(grouped_df)
# Out:
#                PassengerId        Age     SibSp     Parch        Fare  \
# Sex    Pclass
# female 1        469.010638  34.611765  0.553191  0.457447  106.125798
#        2        442.960526  28.722973  0.486842  0.605263   21.970121
#        3        399.590278  21.750000  0.895833  0.798611   16.118810
# male   1        455.590164  41.281386  0.311475  0.278689   67.226127
#        2        447.814815  30.740707  0.342593  0.222222   19.741782
#        3        453.761628  26.523586  0.502907  0.226744   12.659106
#
#                Survival
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.136628
# <ipython-input-13-0e654a6b4544>:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
# Set up the matplotlib figure
plt.figure(figsize=(14, 6))

# Plot the distribution of age for females
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
sns.histplot(Titanic_df[Titanic_df['Sex'] == 'female'], x='Age', hue='Survival', multiple='stack', kde=True, palette=['#1f77b4', '#ff7f0e'])

plt.title('Female')

# Plot the distribution of age for males
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
sns.histplot(Titanic_df[Titanic_df['Sex'] == 'male'], x='Age', hue='Survival', multiple='stack', kde=True, palette=['#1f77b4', '#ff7f0e'])
plt.title('Male')

# Common title for both plots
plt.suptitle('Age and Sex distributions')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Factors that might influence a person's likelihood of survival in the context of the Titanic sinking for this case is Pclass(Passenger Class), sex, age,SibSp (Number of Siblings/Spouses),Parch (Number of Parents/Children),
# lets visualize the dataset for Pclass, sex, age, SibSp (Number of Siblings/Spouses),Parch (Number of Parents/Children) for surived passengers


# Convert 'Pclass' to an integer, handling NaN values appropriately
# Titanic_df['Pclass'] = Titanic_df['Pclass'].fillna(0).astype(int)


# Visualizing survival based on socio-economic status (Pclass)
plt.figure(figsize=(6, 4))
sns.countplot(x='Pclass', hue='Survival', data=Titanic_df, palette='Oranges')
plt.title('Survival Count based on Socio-Economic Status (Pclass)')
plt.xlabel('Pclass (Passenger Class)')
plt.ylabel('Count')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming Titanic_df is your DataFrame

# Calculate the correlation matrix
corr_matrix = Titanic_df.corr()

# Generate a heatmap
plt.figure(figsize=(10, 8)) # Size of the figure
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=.5)
plt.title('Correlation Matrix of Titanic Survival Dataset')
plt.show()
# Out:
# <ipython-input-16-be9066e1a081>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = Titanic_df.corr()

# %% [markdown]
# # Feature Engineering and Data Processing

# %%
# Check for missing values
missing_values = Titanic_df.isnull().sum()
missing_values
# Out:
# PassengerId      0
# Pclass           2
# Name             0
# Sex              0
# Age            176
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# Survival         0
# dtype: int64

# %%
#visualize the missing data
sns.heatmap(Titanic_df.isnull(), cmap='winter', cbar=False)
plt.show()

# %%
# Check if there are any '0' values in 'Pclass' before conversion
zero_count = (Titanic_df['Pclass'] == 0).sum()
print(f"Number of '0' values in 'Pclass': {zero_count}")
# Out:
# Number of '0' values in 'Pclass': 0

# %%
# Remove rows where 'Pclass' is '0' or NaN
Titanic_df = Titanic_df[Titanic_df['Pclass'].isin([1, 2, 3])]

# %%
Titanic_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1     3.0                            Braund, Mr. Owen Harris
# 1              2     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3     3.0                             Heikkinen, Miss. Laina
# 3              4     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5     3.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886     2.0                              Montvila, Rev. Juozas
# 886          887     1.0                       Graham, Miss. Margaret Edith
# 887          888     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 888          889     1.0                              Behr, Mr. Karl Howell
# 889          890     3.0                                Dooley, Mr. Patrick
#
# ...

# %%
categorical_columns = Titanic_df.select_dtypes(include='object').columns
Titanic_df[categorical_columns] = Titanic_df[categorical_columns].fillna('Unknown')
# Out:
# <ipython-input-45-98bc904db134>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Titanic_df[categorical_columns] = Titanic_df[categorical_columns].fillna('Unknown')

# %%
numerical_columns = Titanic_df.select_dtypes(include=['int64', 'float64']).columns
Titanic_df[numerical_columns] = Titanic_df[numerical_columns].fillna(Titanic_df[numerical_columns].mean())
# Out:
# <ipython-input-46-1441a451ddf9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Titanic_df[numerical_columns] = Titanic_df[numerical_columns].fillna(Titanic_df[numerical_columns].mean())

# %%
# Chcek if any missing value is left after handling
print(Titanic_df.isnull().sum())
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survival       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


# Convert categorical features to numerical using LabelEncoder
label_encoder = LabelEncoder()
Titanic_df['Sex'] = label_encoder.fit_transform(Titanic_df['Sex'])
# Out:
# <ipython-input-48-11437fd24ac8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Titanic_df['Sex'] = label_encoder.fit_transform(Titanic_df['Sex'])

# %%
Titanic_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1     3.0                            Braund, Mr. Owen Harris
# 1              2     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3     3.0                             Heikkinen, Miss. Laina
# 3              4     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5     3.0                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 885          886     2.0                              Montvila, Rev. Juozas
# 886          887     1.0                       Graham, Miss. Margaret Edith
# 887          888     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 888          889     1.0                              Behr, Mr. Karl Howell
# 889          890     3.0                                Dooley, Mr. Patrick
#
# ...

# %%
# Drop columns that are not likely to be useful for prediction
columns_to_drop = ['Name', 'Ticket', 'Fare', 'Embarked']

Titanic_df = Titanic_df.drop(columns=columns_to_drop)

# %%
Titanic_df
# Out:
#      PassengerId  Pclass  Sex        Age  SibSp  Parch  Survival
# 0              1     3.0    1  22.000000      1      0         0
# 1              2     1.0    0  38.000000      1      0         1
# 2              3     3.0    0  26.000000      0      0         1
# 3              4     1.0    0  35.000000      1      0         1
# 4              5     3.0    1  35.000000      0      0         0
# ..           ...     ...  ...        ...    ...    ...       ...
# 885          886     2.0    1  27.000000      0      0         0
# 886          887     1.0    0  19.000000      0      0         1
# 887          888     3.0    0  29.713722      1      2         0
# 888          889     1.0    1  26.000000      0      0         1
# 889          890     3.0    1  32.000000      0      0         0
#
# [888 rows x 7 columns]

# %% [markdown]
# Seperating Target and Features

# %%
# Separate features and target variable
X = Titanic_df.drop('Survival', axis=1)
y = Titanic_df['Survival']

# %% [markdown]
# Data Splitting

# %%
# Split the features into training and testing sets
X_train = X.iloc[:650]
X_test = X.iloc[650:650+240]

# Split the target variable into training and testing sets
y_train = y.iloc[:650]
y_test = y.iloc[650:650+240]

# %%
print(X.shape)  # Should be at least (890, number_of_features)
print(y.shape)  # Should be at least (890,)
# Out:
# (888, 6)
# (888,)

# %%
print("Total rows in the dataset:", X.shape[0])
print("Number of training samples:", X_train.shape[0])
print("Number of testing samples:", X_test.shape[0])
# Out:
# Total rows in the dataset: 888
# Number of training samples: 650
# Number of testing samples: 238

# %%
# from sklearn.preprocessing import StandardScaler


# # Initialize the StandardScaler
# scaler = StandardScaler()

# # Fit the scaler on the training data and transform both the training and test data
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# %%
# # Over-sampling Technique

# from imblearn.over_sampling import SMOTE

# smote = SMOTE(random_state=42)
# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %% [markdown]
# # Models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# Define the parameter grid
param_grid = {
    'max_depth': [2, 3, 5, 7, 10, 6, 8, 10 , None],  # Include None to not limit the depth of the tree
    'n_estimators': [10, 50, 100, 200]  # Number of trees in the forest
}

# Create the RandomForestClassifier model
rfc = RandomForestClassifier(criterion="entropy", random_state=100)

# Instantiate the GridSearchCV object
grid_clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the model with the grid search
grid_clf.fit(X_train, y_train)

# Print the best parameters and the best score
print(f"Best parameters: {grid_clf.best_params_}")
print(f"Best accuracy: {grid_clf.best_score_:.4f}")

# Get the best estimator and use it to predict on the test set
best_clf = grid_clf.best_estimator_
y_pred = best_clf.predict(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro', zero_division=0)
recall = recall_score(y_test, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_test, y_pred, average='macro', zero_division=0)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Balanced Accuracy: {balanced_accuracy:.4f}')

# Confusion matrix and classification report
confusion_mat = confusion_matrix(y_test, y_pred)
print(f'Confusion matrix: \n{confusion_mat}')
print(f'Classification report:\n{classification_report(y_test, y_pred)}')


# Visualize the confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=['Not Survived', 'Survived'], cmap=plt.cm.Blues, normalize='all')
plt.title('Normalized Confusion Matrix')
plt.grid(False)
plt.show()
# Out:
# Best parameters: {'max_depth': 5, 'n_estimators': 200}
# Best accuracy: 0.8046
# Accuracy: 0.8319
# Precision: 0.8197
# Recall: 0.8129
# F1 Score: 0.8160
# Balanced Accuracy: 0.8129
# Confusion matrix:
# [[134  18]
#  [ 22  64]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       152
#            1       0.78      0.74      0.76        86
#
#     accuracy                           0.83       238
#    macro avg       0.82      0.81      0.82       238
# weighted avg       0.83      0.83      0.83       238

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Define the parameter grid
param_grid = {
    'max_depth': [None, 3, 5, 7, 10],  # Max depth of the tree, including None to not constrain depth
    'min_samples_split': [2, 5, 10, 20]  # Minimum number of samples required to split a node
}

# Create the DecisionTreeClassifier model
dtc = DecisionTreeClassifier(criterion="entropy", random_state=100)

# Instantiate the GridSearchCV object
grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the model with the grid search
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy from cross-validation: {grid_search.best_score_:.4f}")

# Get the best estimator and use it to predict on the test set
best_dtc = grid_search.best_estimator_
y_pred = best_dtc.predict(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro', zero_division=0)
recall = recall_score(y_test, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_test, y_pred, average='macro', zero_division=0)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Balanced Accuracy: {balanced_accuracy:.4f}')

# Confusion matrix and classification report
print('Confusion matrix:')
print(confusion_matrix(y_test, y_pred))
print('Classification report:')
print(classification_report(y_test, y_pred))

# If you want to add a visual representation of the confusion matrix, you could add the following:
# ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# plt.show()
# Visualize the confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=['Not Survived', 'Survived'], cmap=plt.cm.Blues, normalize='all')
plt.title('Normalized Confusion Matrix')
plt.grid(False)
plt.show()
# Out:
# Best parameters: {'max_depth': 5, 'min_samples_split': 2}
# Best accuracy from cross-validation: 0.7831
# Accuracy: 0.8361
# Precision: 0.8219
# Recall: 0.8389
# F1 Score: 0.8276
# Balanced Accuracy: 0.8389
# Confusion matrix:
# [[126  26]
#  [ 13  73]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       152
#            1       0.74      0.85      0.79        86
#
#     accuracy                           0.84       238
#    macro avg       0.82      0.84      0.83       238
# weighted avg       0.85      0.84      0.84       238

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Define the parameter grid
param_grid = {
    'C': np.logspace(-4, 4, 20),  # Range of values for the inverse of regularization strength
    'penalty': ['l1', 'l2']  # Norms used for regularization
}

# Note: 'liblinear' solver supports both L1 and L2 regularization.
# For large datasets consider using 'saga' which also supports 'none' penalty.
logreg = LogisticRegression(solver='liblinear', random_state=100)

# Instantiate the GridSearchCV object
grid_search = GridSearchCV(estimator=logreg, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the model with the grid search
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy from cross-validation: {grid_search.best_score_:.4f}")

# Get the best estimator and use it to predict on the test set
best_logreg = grid_search.best_estimator_
y_pred = best_logreg.predict(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro', zero_division=0)
recall = recall_score(y_test, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_test, y_pred, average='macro', zero_division=0)
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

# Print metrics
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Balanced Accuracy: {balanced_accuracy:.4f}')

# Confusion matrix and classification report
print('Confusion matrix:')
print(confusion_matrix(y_test, y_pred))
print('Classification report:')
print(classification_report(y_test, y_pred))

# If you want to add a visual representation of the confusion matrix, you could add the following:
# ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
# plt.show()
# Visualize the confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=['Not Survived', 'Survived'], cmap=plt.cm.Blues, normalize='all')
plt.title('Normalized Confusion Matrix')
plt.grid(False)
plt.show()
# Out:
# Best parameters: {'C': 1.623776739188721, 'penalty': 'l2'}
# Best accuracy from cross-validation: 0.7846
# Accuracy: 0.7899
# Precision: 0.7727
# Recall: 0.7699
# F1 Score: 0.7712
# Balanced Accuracy: 0.7699
# Confusion matrix:
# [[128  24]
#  [ 26  60]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.84       152
#            1       0.71      0.70      0.71        86
#
#     accuracy                           0.79       238
#    macro avg       0.77      0.77      0.77       238
# weighted avg       0.79      0.79      0.79       238
